# %%
import pandas as pd
from scipy.stats import anderson

df = pd.read_csv('input.csv')
# Anderson-Darling test
anderson_pre = anderson(df[df['Location'] == 'Lab']['Pre-molt'])
anderson_post = anderson(df[df['Location'] == 'Lab']['Post-molt'])

# Display results briefly
def display_anderson_result(test_result, label):
    print(f'\n{label} - Anderson-Darling Test')
    print(f'Statistic: {test_result.statistic}')
    print('Critical Values:', test_result.critical_values)
    print('Significance Levels:', test_result.significance_level)

# Display results for pre- and post-molt sizes




# Anderson-Darling test
anderson_pre = anderson(df[df['Location'] == 'Field']['Pre-molt'])
anderson_post = anderson(df[df['Location'] == 'Field']['Post-molt'])

# Display results briefly
def display_anderson_result(test_result, label):
    print(f'\n{label} - Anderson-Darling Test')
    print(f'Statistic: {test_result.statistic}')
    print('Critical Values:', test_result.critical_values)
    print('Significance Levels:', test_result.significance_level)

# Display results for pre- and post-molt sizes



print(f'---------------------------------------------------------------------------------------------------------------------------------')


import pandas as pd
from scipy.stats import kstest

df = pd.read_csv('input.csv')

# Kolmogorov-Smirnov test against normal distribution
ks_pre =   kstest(df[df['Location'] == 'Lab']['Pre-molt'], 'norm', args=(df[df['Location'] == 'Lab']['Pre-molt'].mean(), df[df['Location'] == 'Lab']['Pre-molt'].std()))
ks_post = kstest(df[df['Location'] == 'Lab']['Post-molt'], 'norm', args=(df[df['Location'] == 'Lab']['Post-molt'].mean(),df[df['Location'] == 'Lab']['Post-molt'].std()))


ks_pre =   kstest(df[df['Location'] == 'Field']['Pre-molt'], 'norm', args=(df[df['Location'] == 'Lab']['Pre-molt'].mean(), df[df['Location'] == 'Lab']['Pre-molt'].std()))
ks_post = kstest(df[df['Location'] == 'Field']['Post-molt'], 'norm', args=(df[df['Location'] == 'Lab']['Post-molt'].mean(),df[df['Location'] == 'Lab']['Post-molt'].std()))






import pandas as pd
from scipy.stats import cramervonmises

df=pd.read_csv('input.csv')

cvm_pre = cramervonmises(df[df['Location'] == 'Lab']['Pre-molt'], 'norm')
cvm_post = cramervonmises(df[df['Location'] == 'Lab']['Post-molt'], 'norm')




cvm_pre = cramervonmises(df[df['Location'] == 'Field']['Pre-molt'], 'norm')
cvm_post = cramervonmises(df[df['Location'] == 'Field']['Post-molt'], 'norm')



print(f'---------------------------------------------------------------------------------------------------------------------------------')



import pandas as pd
from scipy.stats import shapiro

df=pd.read_csv('input.csv')

# Shapiro-Wilk test
shapiro_pre = shapiro(df[df['Location'] == 'Field']['Pre-molt'])
shapiro_post = shapiro(df[df['Location'] == 'Field']['Post-molt'])


shapiro_pre = shapiro(df[df['Location'] == 'Lab']['Pre-molt'])
shapiro_post = shapiro(df[df['Location'] == 'Lab']['Post-molt'])



display_anderson_result(anderson_pre, 'Pre-Molt Size for Lab data')
print(f'\n* Kolmogorov-Smirnov Test (Pre-Molt) for Lab: {ks_pre}')
print(f'\n* Cramér-von Mises Test (Pre-Molt) for lab data: {cvm_pre}')
print(f'\n* Shapiro-Wilk Test (Pre-Molt) for Lab Data: {shapiro_pre}')

print(f'---------------------------------------------------------------------------------------------------------------------------------')


display_anderson_result(anderson_pre, 'Pre-Molt Size for filed data')
print(f'\n* Kolmogorov-Smirnov Test (Pre-Molt) for Field: {ks_pre}')
print(f'\n* Cramér-von Mises Test (Pre-Molt) for filed data: {cvm_pre}')
print(f'\n* Shapiro-Wilk Test (Pre-Molt) for Lab Data: {shapiro_pre}')

print(f'---------------------------------------------------------------------------------------------------------------------------------')

display_anderson_result(anderson_post, 'Post-Molt Size for Lab data')
print(f'\n* Kolmogorov-Smirnov Test (Post-Molt) for LAb: {ks_post}')
print(f'\n* Cramér-von Mises Test (Post-Molt) for lab data: {cvm_post}')
print(f'\n* Shapiro-Wilk Test (Post-Molt) for Lab Data: {shapiro_post}')






print(f'---------------------------------------------------------------------------------------------------------------------------------')

display_anderson_result(anderson_post, 'Post-Molt Size for field data')
print(f'\n* Kolmogorov-Smirnov Test (Post-Molt) for Field: {ks_post}')
print(f'\n* Cramér-von Mises Test (Post-Molt) for field data: {cvm_post}')
print(f'\n* Shapiro-Wilk Test (Post-Molt) for Lab Data: {shapiro_post}')
# Out:
# ---------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------------------------
#
# Pre-Molt Size for Lab data - Anderson-Darling Test
# Statistic: 1.8990674427261496
# Critical Values: [0.557 0.634 0.761 0.888 1.056]
# Significance Levels: [15.  10.   5.   2.5  1. ]
#
# * Kolmogorov-Smirnov Test (Pre-Molt) for Lab: KstestResult(statistic=0.5196598960212944, pvalue=2.0954610932377597e-28, statistic_location=131.6, statistic_sign=-1)
#
# * Cramér-von Mises Test (Pre-Molt) for lab data: CramerVonMisesResult(statistic=37.00000000000001, pvalue=0)
#
# * Shapiro-Wilk Test (Pre-Molt) for Lab Data: ShapiroResult(statistic=0.8615104215794123, pvalue=2.1427046241940032e-17)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# ...
