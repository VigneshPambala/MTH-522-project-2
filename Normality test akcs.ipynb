# %%
import pandas as pd
from scipy.stats import anderson

df = pd.read_csv('input.csv')
# Anderson-Darling test
anderson_pre_lab = anderson(df[df['Location'] == 'Lab']['Pre-molt'])
anderson_post_lab = anderson(df[df['Location'] == 'Lab']['Post-molt'])

# Display results briefly
def display_anderson_result(test_result, label):
    print(f'\n{label} - Anderson-Darling Test')
    print(f'Statistic: {test_result.statistic}')
    print('Critical Values:', test_result.critical_values)
    print('Significance Levels:', test_result.significance_level)

# Display results for pre- and post-molt sizes




# Anderson-Darling test
anderson_pre_field = anderson(df[df['Location'] == 'Field']['Pre-molt'])
anderson_post_field = anderson(df[df['Location'] == 'Field']['Post-molt'])

# Display results briefly
def display_anderson_result(test_result, label):
    print(f'\n{label} - Anderson-Darling Test')
    print(f'Statistic: {test_result.statistic}')
    print('Critical Values:', test_result.critical_values)
    print('Significance Levels:', test_result.significance_level)

# Display results for pre- and post-molt sizes



import pandas as pd
from scipy.stats import kstest

df = pd.read_csv('input.csv')

# Kolmogorov-Smirnov test against normal distribution
ks_pre_lab =   kstest(df[df['Location'] == 'Lab']['Pre-molt'], 'norm', args=(df[df['Location'] == 'Lab']['Pre-molt'].mean(), df[df['Location'] == 'Lab']['Pre-molt'].std()))
ks_post_lab = kstest(df[df['Location'] == 'Lab']['Post-molt'], 'norm', args=(df[df['Location'] == 'Lab']['Post-molt'].mean(),df[df['Location'] == 'Lab']['Post-molt'].std()))


ks_pre_field =   kstest(df[df['Location'] == 'Field']['Pre-molt'], 'norm', args=(df[df['Location'] == 'Lab']['Pre-molt'].mean(), df[df['Location'] == 'Lab']['Pre-molt'].std()))
ks_post_field = kstest(df[df['Location'] == 'Field']['Post-molt'], 'norm', args=(df[df['Location'] == 'Lab']['Post-molt'].mean(),df[df['Location'] == 'Lab']['Post-molt'].std()))






import pandas as pd
from scipy.stats import cramervonmises

df=pd.read_csv('input.csv')

cvm_pre_lab = cramervonmises(df[df['Location'] == 'Lab']['Pre-molt'], 'norm')
cvm_post_lab = cramervonmises(df[df['Location'] == 'Lab']['Post-molt'], 'norm')




cvm_pre_field = cramervonmises(df[df['Location'] == 'Field']['Pre-molt'], 'norm')
cvm_post_field= cramervonmises(df[df['Location'] == 'Field']['Post-molt'], 'norm')



print(f'---------------------------------------------------------------------------------------------------------------------------------')



import pandas as pd
from scipy.stats import shapiro

df=pd.read_csv('input.csv')

# Shapiro-Wilk test
shapiro_pre_field = shapiro(df[df['Location'] == 'Field']['Pre-molt'])
shapiro_post_field = shapiro(df[df['Location'] == 'Field']['Post-molt'])


shapiro_pre_lab = shapiro(df[df['Location'] == 'Lab']['Pre-molt'])
shapiro_post_lab = shapiro(df[df['Location'] == 'Lab']['Post-molt'])



display_anderson_result(anderson_pre_lab, 'Pre-Molt Size for Lab data')
print(f'\n* Kolmogorov-Smirnov Test (Pre-Molt) for Lab: {ks_pre_lab}')
print(f'\n* Cramér-von Mises Test (Pre-Molt) for lab data: {cvm_pre_lab}')
print(f'\n* Shapiro-Wilk Test (Pre-Molt) for Lab Data: {shapiro_pre_lab}')

print(f'---------------------------------------------------------------------------------------------------------------------------------')

display_anderson_result(anderson_pre_field, 'Pre-Molt Size for filed data')
print(f'\n* Kolmogorov-Smirnov Test (Pre-Molt) for Field: {ks_pre_field}')
print(f'\n* Cramér-von Mises Test (Pre-Molt) for filed data: {cvm_pre_field}')
print(f'\n* Shapiro-Wilk Test (Pre-Molt) for Field Data: {shapiro_pre_field}')

print(f'---------------------------------------------------------------------------------------------------------------------------------')

display_anderson_result(anderson_post_lab, 'Post-Molt Size for Lab data')
print(f'\n* Kolmogorov-Smirnov Test (Post-Molt) for LAb: {ks_post_lab}')
print(f'\n* Cramér-von Mises Test (Post-Molt) for lab data: {cvm_post_lab}')
print(f'\n* Shapiro-Wilk Test (Post-Molt) for Lab Data: {shapiro_post_lab}')

print(f'---------------------------------------------------------------------------------------------------------------------------------')

display_anderson_result(anderson_post_field, 'Post-Molt Size for field data')
print(f'\n* Kolmogorov-Smirnov Test (Post-Molt) for Field: {ks_post_field}')
print(f'\n* Cramér-von Mises Test (Post-Molt) for field data: {cvm_post_field}')
print(f'\n* Shapiro-Wilk Test (Post-Molt) for Field Data: {shapiro_post_field}')
# Out:
# ---------------------------------------------------------------------------------------------------------------------------------
#
# Pre-Molt Size for Lab data - Anderson-Darling Test
# Statistic: 9.255798135902864
# Critical Values: [0.57  0.649 0.779 0.908 1.08 ]
# Significance Levels: [15.  10.   5.   2.5  1. ]
#
# * Kolmogorov-Smirnov Test (Pre-Molt) for Lab: KstestResult(statistic=0.1016323125586237, pvalue=0.0010647315928070202, statistic_location=118.6, statistic_sign=-1)
#
# * Cramér-von Mises Test (Pre-Molt) for lab data: CramerVonMisesResult(statistic=120.33333333333333, pvalue=0)
#
# * Shapiro-Wilk Test (Pre-Molt) for Lab Data: ShapiroResult(statistic=0.8615104215794123, pvalue=2.1427046241940032e-17)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# Pre-Molt Size for filed data - Anderson-Darling Test
# Statistic: 1.8990674427261496
# Critical Values: [0.557 0.634 0.761 0.888 1.056]
# ...
